# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200) # removing dot and give all column names limit of 200

# %% [markdown]
# ## 1 - Understanding Data

# %%
df = pd.read_csv('data_set/coaster_db.csv')
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ## 2 - Data Preparation

# %%
# Choosing particular columns ot using df.drop[['']]
df = df[['coaster_name', 
#     'Length', 'Speed', 
    'Location', 'Status', 
#     'Opening date',
#        'Type', 
    'Manufacturer', 
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude',
    'Type_Main','opening_date_clean', 
#     'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
#     'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
# Making correct data formats
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])
df['year_introduced'] = pd.to_numeric(df['year_introduced'])
df.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
# Rename columns {old:new}
df = df.rename(columns={
    'coaster_name':'Coaster_Name',
    'year_introduced':'Year_Introduced',
    'latitude':'Latitude',
    'longitude':'Longitude',
    'opening_date_clean':'Opening_Date_Clean',
    'speed_mph':'Speed_Mph',
    'height_ft':'Height_ft',
    
})
df.head(2)
# Out:
#          Coaster_Name       Location   Status            Manufacturer  \
# 0  Switchback Railway   Coney Island  Removed  LaMarcus Adna Thompson
# 1   Flip Flap Railway  Sea Lion Park  Removed            Lina Beecher
#
#    Year_Introduced  Latitude  Longitude Type_Main Opening_Date_Clean  \
# 0             1884    40.574    -73.978      Wood         1884-06-16
# 1             1895    40.578    -73.979      Wood         1895-01-01
#
#    Speed_Mph  Height_ft  Inversions_clean  Gforce_clean
# 0        6.0        NaN                 0           2.9
# 1        NaN        NaN                 1          12.0

# %% [markdown]
# ## 3 - Cleaning data

# %%
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Manufacturer           59
# Year_Introduced         0
# Latitude              275
# Longitude             275
# Type_Main               0
# Opening_Date_Clean    250
# Speed_Mph             150
# Height_ft             916
# Inversions_clean        0
# Gforce_clean          725
# dtype: int64

# %%
## finding duplicated row
df.loc[df.duplicated()] ## gives the duplicated row
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date_Clean, Speed_Mph, Height_ft, Inversions_clean, Gforce_clean]
# Index: []

# %%
# indeeper finding the duplicate
df.loc[df.duplicated(subset=['Coaster_Name'])]

# FOund these are duplicated rows in coaster_name columns
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
# lets checks with one coaster_name using query parameter
df.query('Coaster_Name == "Crystal Beach Cyclone"')

## Similarly but year is different
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date_Clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     Speed_Mph  Height_ft  Inversions_clean  Gforce_clean
# 39       60.0        NaN                 0           4.0
# 43       60.0        NaN                 0           4.0

# %%
# Save the unique values of the dataset
# drop = True -- Removes another column of index
# should satisfy all the subset

df = df.loc[~df.duplicated(subset=['Coaster_Name','Opening_Date_Clean','Location'])].reset_index(drop=True)

# %%
df.shape
# Out:
# (990, 13)

# %% [markdown]
# # 4 - Feature Understanding

# %% [markdown]
# ## Univariate Analysis

# %%
## Year Introduced of the Roller coaster
ax = df['Year_Introduced'].value_counts().head(10) \
 .plot(kind='bar',title="Top 10 Roller Coasters Year Introduced") 
ax.set_xlabel('Years')
ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ## Distribution Identify

# %%
# Speed
sp = df['Speed_Mph'] \
 .plot(kind='hist',bins=20,title = "Coaster Speed Distributed (mph)") 
sp.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
# Using KDE get even more understanding
sp = df['Speed_Mph'] \
     .plot(kind='kde',title="Speed of Coaster in mph")
sp.set_xlabel('Speed in mph')

## Even More Clear Understanding
# Out:
# Text(0.5, 0, 'Speed in mph')

# %% [markdown]
# # 5 - Feature Relationship

# %%
# Normal matplotlib
df.plot(kind='scatter',x='Speed_Mph',y='Height_ft')
plt.show()

# %%
# Using Seaborn
sns.scatterplot(
    x='Speed_Mph',
    y='Height_ft',
    hue='Year_Introduced',
    data=df
)
plt.show()

# %%
## Compare more than one variable
sns.pairplot(df,vars=['Year_Introduced','Height_ft','Speed_Mph',], hue='Status')
plt.show()
# Out:
# C:\Users\SIVA\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Finding Correlation

# %%
## Correlation
df_corr = df[['Year_Introduced','Height_ft','Speed_Mph','Gforce_clean','Inversions_clean']].dropna().corr()
df_corr
# Out:
#                   Year_Introduced  Height_ft  Speed_Mph  Gforce_clean  \
# Year_Introduced          1.000000   0.135413   0.171978      0.160247
# Height_ft                0.135413   1.000000   0.733999      0.466482
# Speed_Mph                0.171978   0.733999   1.000000      0.607383
# Gforce_clean             0.160247   0.466482   0.607383      1.000000
# Inversions_clean        -0.209887  -0.079736  -0.028705      0.275991
#
#                   Inversions_clean
# Year_Introduced          -0.209887
# Height_ft                -0.079736
# Speed_Mph                -0.028705
# Gforce_clean              0.275991
# Inversions_clean          1.000000

# %%
sns.heatmap(df_corr, annot=True)  # annot = True means ploting raw value inside heat map
plt.show()

# %% [markdown]
# ## Q1 -  What are the locations is the faster roller coaster (minimum of 10)

# %%
ax = df.query('Location != "Other"') \
  .groupby('Location')['Speed_Mph'] \
  .agg(['mean','count']) \
  .query('count >= 10') \
  .sort_values('mean')['mean'] \
  .plot(kind='barh',title="Top 10 faster roller coaster based on location")

ax.set_xlabel('Average Coaster Speed')
plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_Mph',
#        'Height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')
